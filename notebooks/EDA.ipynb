# %%
import pandas as pd
import plotly.express as px
import streamlit as st

df = pd.read_csv(r"c:/users/usuario/vehicles_project/vehicles_us.csv")
print(df.head())
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     NaN  2019-02-07           79
# 3    automatic  pickup         NaN     NaN  2019-03-22            9
# 4    automatic   sedan       black     NaN  2019-04-02           28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %%
#Configuración de la página
st.set_page_config(page_title="Vehicle Dashboard", layout="wide")

st.title("Data viewer")

#Cargar datos
df = pd.read_csv(r"c:/users/usuario/vehicles_project/vehicles_us.csv")

# Crear columna manufacturer a partir de model
df["manufacturer"] = df["model"].str.split().str[0]

# Limpiar algunas filas para evitar problemas en gráficos
df_graphs = df.dropna(subset=["odometer", "price", "model_year"]).copy()

#========================================
# SECCIÓN PARA CUMPLIR CON REQUERIMIENTOS
# =======================================

st.header("Project Vehicles Charts")

build_histogram = st.checkbox("Build histogram")
if build_histogram:
    st.write("Histogram for the odometer column")
    fig_hist_req = px.histogram(
        df_graphs,
        x="odometer",
        title="Odometer distribution"
    )
    st.plotly_chart(fig_hist_req, width="stretch")
    
build_scatter = st.checkbox("Build scatter plot")
if build_scatter:
    st.write("Scatter plot: price vs odometer")
    fig_scatter_req = px.scatter(
        df_graphs,
        x="odometer",
        y="price",
        title="Price vs odometer"
    )
    st.plotly_chart(fig_scatter_req, width="stretch")
    
# =========================
# 1. FILTRO POR FABRICANTE
# =========================

manufacturer_counts = df["manufacturer"].value_counts()

checkbox = st.checkbox("Include manufacturers with less than 1000 ads", value=True)

if not checkbox:
    valid_manufacturers = manufacturer_counts[manufacturer_counts >= 1000].index
    df = df[df["manufacturer"].isin(valid_manufacturers)]

# Mostrar tabla
st.dataframe(df)

# =========================
# 2. VEHICLE TYPES
# =========================

st.header("Vehicle types by manufacturer")

df_grouped = df.groupby(["manufacturer", "type"]).size().reset_index(name="count")

fig_bar = px.bar(
    df_grouped,
    x="manufacturer",
    y="count",
    color="type",
    title="Vehicle types by manufacturer"
)

st.plotly_chart(fig_bar, width="stretch")

# =========================
# 3. HISTOGRAMA CONDITION
# =========================

st.header("Histogram of condition vs model_year")

fig_hist = px.histogram(
    df,
    x="model_year",
    color="condition",
    title="Histogram of condition vs model_year"
)

st.plotly_chart(fig_hist, width="stretch")

# =========================
# 4. COMPARADOR DE PRECIOS
# =========================

st.header("Compare price distribution between manufacturers")

manufacturers = sorted(df["manufacturer"].dropna().unique())

col1, col2 = st.columns(2)

with col1:
    m1 = st.selectbox("Select manufacturer 1", manufacturers, index=0)

with col2:
    default_index_2 = 1 if len(manufacturers) > 1 else 0
    m2 = st.selectbox("Select manufacturer 2", manufacturers, index=default_index_2)

normalize = st.checkbox("Normalize histogram", value=True)

df_m1 = df[df["manufacturer"] == m1]
df_m2 = df[df["manufacturer"] == m2]

df_compare = pd.concat([
    df_m1.assign(source=m1),
    df_m2.assign(source=m2)
])

histnorm = "percent" if normalize else None

fig_price = px.histogram(
    df_compare,
    x="price",
    color="source",
    histnorm=histnorm,
    barmode="overlay",
    title="Price distribution comparison"
)

st.plotly_chart(fig_price, width="stretch")
# Out:
# 2026-03-29 19:18:36.920 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:36.924 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.591
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\usuario\anaconda3\envs\vehicles_env311\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-03-29 19:18:37.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.846 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.850 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.851 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.855 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.857 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.868 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.893 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.910 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.916 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:37.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.051 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.389 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.390 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.394 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.396 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.405 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.519 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.521 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.528 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.583 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.587 Session state does not function when running a script without `streamlit run`
# 2026-03-29 19:18:38.590 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.600 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.680 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.682 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.684 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.685 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.895 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 19:18:38.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
